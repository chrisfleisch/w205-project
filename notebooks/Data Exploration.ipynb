# %%
import re
import pandas as pd
import numpy as np

from fixerio import Fixerio
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from measurement.measures import Volume

# %%
va_df = pd.read_csv('../data_source/va_prices.csv', skiprows=1)
va_df.columns = va_df.columns.str.lower()

# %%
va_df = va_df[va_df.description.str.contains('WHISKEY') | va_df.description.str.contains('WHISKY')]
va_df.head()
# Out:
#                 description   code                       brand   size  age  \
# 0  STRAIGHT BOURBON WHISKEY  21228     1792 Bourbon Full Proof  750ml  NaN
# 1  STRAIGHT BOURBON WHISKEY  21232    1792 Port Finish Bourbon  750ml  NaN
# 2  STRAIGHT BOURBON WHISKEY  21244  1792 Single Barrel Bourbon  750ml  NaN
# 3  STRAIGHT BOURBON WHISKEY  21236    1792 Small Batch Bourbon  750ml  NaN
# 4  STRAIGHT BOURBON WHISKEY  21242    1792 Sweet Wheat Bourbon  750ml  NaN
#
#    proof    price
# 0  125.0  $47.99
# 1   88.9  $42.99
# 2   98.6  $42.99
# 3   93.7  $33.99
# 4   91.2  $39.99

# %%
va_df.describe()
# Out:
#                 code       proof
# count     871.000000  871.000000
# mean    20912.814007   84.514696
# std     19615.108155   13.127495
# min       137.000000    0.000000
# 25%      6897.500000   80.000000
# 50%     17920.000000   80.000000
# 75%     26114.500000   90.000000
# max    100124.000000  136.200000

# %%
va_df.brand.isnull().any()
# Out:
# False

# %%
def my_va_transform(s):
    """Function to transform brand
    * make lower
    * do specific regex replacements
    * remove product types ex: 'bourbon', 'whiskey'
    * sort the words in the brand
    """
    s = s.lower()
    
    replacements = {"^gentleman jack whiskey$": "jack daniel's gentleman jack",
                    "^pritchard": "prichard",
                    "^balcones baby blue corn whiskey$": "balcones baby blue",
                    "^canadian club rye whisky$": "canadian club",
                    "^catoctin creek roundstone rye whisky$": "catoctin creek roundstone rye",
                    "^e h taylor jr. straight rye$": "colonel e.h. taylor straight rye",
                    "^e h taylor seasoned wood$": "colonel e.h. taylor seasoned wood",
                    "^james e. pepper 1776 rye": "james e. pepper 1776 straight rye",
                    "^lock stock & barrel 16 yr straight rye whiskey$": "lock stock and barrel 16 straight rye",
                    "^michter's us 1 single barrel straight rye$": "michter's us*1",
                    "^michter's us-1 barrel strength rye": "michter's barrel strength rye",
                    "^old overholt$": "old overholt rye",
                    "^wild turkey russell's reserve rye$": "russell's reserve rye 6",
                    "\s7\s": " seven ",
                    "^defiant whisky$": "defiant",
                    "^michter's us1 sour mash$": "michter sour mash",
                    "^red stag": "jim beam red stag",
                    "^four roses 2015 limited edition small batch$": "four roses limited edition 2015",
                    "^four roses 2016 limited edition small batch$": "four roses small batch limited edition 2016",
                    "^i w harper bourbon$": "i.w. harper",
                    "^jesse james bourbon whiskey$": "original jesse james",
                    "^the": " ",
                    "scotch$": " ",
                    "-": " ",
                    }
    for k, v in replacements.items():
        s = re.sub(k, v, s)
    
    replace = ['bourbon', 'craft',
               'Year Single Barrel Bourbon',
               '-year Single Barrel Bourbon',
               'whiskey', 'tennessee whiskey', 'tennessee',
               'year', 'yr', '-year single barrel',
               'year single barrel', 'label', "'s",
               'decades', 'whisky', '&', 'single malt', "(", ")",
               "yo", "no.", "irish", "’", "us1",
               ]
    
    for item in replace:
        s = s.replace(item, '')
    
    s = s.split() # remove extra spaces betwen words and sort
    s.sort()
    s = " ".join(s)
    
    return s.strip()

# %%
my_va_transform('12 glenlivet malt single')
# Out:
# '12 glenlivet malt single'

# %%
va_df['alt_brand'] = va_df['brand'].map(lambda x: my_va_transform(x))
va_df.head()
# Out:
#                 description   code                       brand   size  age  \
# 0  STRAIGHT BOURBON WHISKEY  21228     1792 Bourbon Full Proof  750ml  NaN
# 1  STRAIGHT BOURBON WHISKEY  21232    1792 Port Finish Bourbon  750ml  NaN
# 2  STRAIGHT BOURBON WHISKEY  21244  1792 Single Barrel Bourbon  750ml  NaN
# 3  STRAIGHT BOURBON WHISKEY  21236    1792 Small Batch Bourbon  750ml  NaN
# 4  STRAIGHT BOURBON WHISKEY  21242    1792 Sweet Wheat Bourbon  750ml  NaN
#
#    proof    price           alt_brand
# 0  125.0  $47.99      1792 full proof
# 1   88.9  $42.99     1792 finish port
# 2   98.6  $42.99   1792 barrel single
# 3   93.7  $33.99     1792 batch small
# 4   91.2  $39.99     1792 sweet wheat

# %%
def my_size_transform(s):
    if 'ml' in s:
        v = Volume(milliliter=s.replace('ml', ''))
    elif 'L' in s:
        v = Volume(liter=s.replace('L', ''))
    return v.us_oz

# %%
va_df['oz'] = va_df['size'].map(lambda x: my_size_transform(x))
va_df['alt_price'] = va_df['price'].str.replace('$', '')
va_df['alt_age'] = va_df['age'].str.replace('YR', '')

# %%
w_archive = pd.read_csv('../data_source/reddit_archive.csv',
                        names=['timestamp', 'whisky_name', 'reviewer_username', 'link',
                               'rating', 'style', 'bottle_price', 'review_date'],
                        skiprows=1,
                        parse_dates=['timestamp', 'review_date'])

# %%
w_archive['rating'] = pd.to_numeric(w_archive['rating'], errors='coerce')
#w_archive['bottle_price'] = pd.to_numeric(w_archive['bottle_price'], errors='coerce')
w_archive['timestamp'] = pd.to_datetime(w_archive['timestamp'], errors='coerce')
w_archive['review_date'] = pd.to_datetime(w_archive['review_date'], errors='coerce')
w_archive['whisky_name'] = w_archive.whisky_name.str.lower()
w_archive['style'] = w_archive['style'].str.lower()
w_archive.dtypes
# Out:
# timestamp            datetime64[ns]
# whisky_name                  object
# reviewer_username            object
# link                         object
# rating                      float64
# style                        object
# bottle_price                 object
# review_date          datetime64[ns]
# dtype: object

# %%
#w_archive.head(20)

# %%
fxrio = Fixerio(base='USD')
conversion = fxrio.latest()
import math

def isnumber(num):
    return all(char.isdigit() for char in num)

def transform_currency(s):
    if 'CAD' in str(s) or 'CDN' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['CAD'])
        return new_price
    elif '£' in str(s) or 'GBP' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['GBP'])
        return new_price
    elif 'AUD' in str(s) or 'AUS' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['AUD'])
        return new_price
    elif 'NZD' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['NZD'])
        return new_price
    elif 'EUR' in str(s) or '€' in str(s) or 'Euro' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['EUR'])
        return new_price
    elif 'SEK' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['SEK'])
        return new_price
    elif 'RMB' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['CNY'])
        return new_price
    elif 'DKR' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['DKK'])
        return new_price
    elif 'HKD' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['HKD'])
        return new_price
    elif 'JPY' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['JPY'])
        return new_price
    elif 'ZAR' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['ZAR'])
        return new_price
    elif type(s) == str and isnumber(s):
        # USD
        return s
    elif type(s) == float and math.isnan(s):
        # NAN
        return s
    elif re.match(r"""^\$*\d+\.*\d+$""", s):
        s = s.replace('$', '')
        return s
    else:
        # Convert everything else to NAN
        print(s)
        return None

# %%
w_archive['alt_brand'] = w_archive['whisky_name'].map(lambda x: my_va_transform(x))
w_archive['alt_bottle_price'] = w_archive['bottle_price'].map(lambda x: transform_currency(x))
#w_archive.head(100)
# Out:
# 55 CHF
# 40 euro
# $40 USD
# $38 USD
# $60 USD
# $50 USD
# $65 USD
# $270 ARS

# %%
va_new_brand = va_df['alt_brand'].tolist()
wa_new_whisky = w_archive['alt_brand'].tolist()

# %%
exact_matches = set()
for brand in va_new_brand:
    if brand in wa_new_whisky:
        exact_matches.add(brand)
print('Matches: {}'.format(len(exact_matches)))
exact_matches = list(exact_matches)
exact_matches.sort()
print('\n'.join(exact_matches))
# Out:
# Matches: 239
# 1 edition macallan
# 10 bulleit
# 10 cork west
# 10 eagle rare
# 10 fine macallan oak
# 10 glenmorangie original the
# 10 old rip van winkle
# 101 turkey wild
# 114 dad grand old
# 12 balvenie doublewood
# 12 beam jim signature
# 12 bowmore
# 12 bunnahabhain
# 12 caol ila
# 12 cask double macallan
# 12 castle knappogue
# 12 chivas regal
# 12 craig elijah
# 12 dalmore
# 12 dewar reserve special
# 12 dickel george
# 12 glendronach
# 12 glenfiddich
# 12 glenlivet
# 12 hibiki
# 12 highland park
# 12 jameson
# 12 lagavulin
# 12 macallan
# 12 medley old
# 12 tomatin
# 12 yamazaki
# 14 balvenie caribbean cask
# 15 family pappy reserve van winkle
# 15 fine macallan oak
# 16 aberlour
# 16 and barrel lock rye stock straight
# 17 balvenie doublewood
# 17 fine macallan oak
# 1776 barrel e. james pepper proof rye
# 1776 e. james pepper rye straight
# 1783 evan williams
# 1792 batch small
# 1792 finish port
# 1792 full proof
# 1792 high rye
# 1792 sweet wheat
# 18 chivas regal
# 18 glenlivet
# 18 jameson
# 18 laphroaig
# 18 macallan
# 18 oban
# 18 talisker
# 1843 david nicholson
# 1870 forester old
# 2 edition macallan
# 2015 edition four limited roses
# 2016 batch edition four limited roses small
# 2016 birthday forester old
# 21 archive glenlivet
# 21 balvenie portwood
# 21 bushmills
# 21 rosebank
# 25 highland park
# 25 laphroaig
# 25 talisker
# 30 caol ila
# 30 talisker
# 40 lot
# 46 maker mark
# 6 reserve russell rye
# 75th anniversary crown monarch royal
# 8 dickel george
# 8 islay mist
# 8 lagavulin
# 81 turkey wild
# age ancient
# american westland
# angel envy rye
# ardbeg auriverdes
# ardbeg committee cove dark release
# ardbeg corryvreckan
# ardbeg perpetuum
# auchentoshan three wood
# baby balcones blue
# baby hudson
# barrel barrel daniel jack proof single
# barrel beam jim single
# barrel creek forty select
# barrel creek knob reserve single
# barrel crown hand royal selected
# barrel daniel jack single
# barrel evan single williams
# barrel four roses single
# barrel michter rye strength
# barrel reserve russell rye single
# barrel reserve russell single
# barrel single wathen
# basil hayden
# batch craig elijah small
# batch four roses small
# batch hirsch reserve small
# batch jefferson small very
# batch michter small
# batch small teeling
# bay little oban
# beam black jim
# beam bonded jim
# beam choice jim
# beam cider hardcore jim red stag
# beam cinnamon jim red spiced stag with
# beam cut devil jim
# beam double jim oak
# beam honey jim
# beam jim
# beam jim red stag
# beam jim rye
# belle meade
# black bush bushmills
# black crown royal
# black double johnnie walker
# black evan williams
# black famous grouse smoky
# black grouse
# black johnnie walker
# black velvet
# black virginia
# blue johnnie walker
# booker
# booker rye
# bradan orach speyburn
# breckenridge
# breed rare turkey wild
# buffalo trace
# bulleit
# bulleit rye
# bunnahabhain toiteach
# canadian club
# canadian mist
# cask finish groth jefferson reserve
# cask glenrothes reserve
# cask glenrothes reserve sherry
# cask laphroaig quarter
# cask macallan rare
# cask maker mark strength
# catoctin creek roundstone rye
# chivas extra regal
# clan macgregor
# club haig
# cock fighting
# coffey grain nikka
# colorado stranahan
# comfort southern
# copper fox rye
# creek knob
# creek knob maple smoked
# creek knob rye
# crow old
# crow old reserve
# crown harvest northern royal rye
# crown reserve royal special
# crown royal
# crown seagram seven
# cutty sark
# d'or glenmorangie nectar
# dalwhinnie distiller edition
# daniel gentleman jack jack
# daniel honey jack
# dark highland origins park
# dead guy rogue
# defiant
# dew phoenix tullamore
# dew tullamore
# dewar highlander honey
# dewar white
# dickel george rye
# distiller edition talisker
# double high rye west
# double oaked reserve woodford
# early times
# edition fire highland park
# elmer lee t
# evan green williams
# famous grouse
# filibuster
# fill first glenlivet nadurra
# forester old
# forester old signature
# forgiven turkey wild
# four grain hudson
# gentleman virginia
# glenlivet nadurra oloroso
# glenmorangie lasanta
# glenmorangie milsean
# glenmorangie quinta ruban
# glenmorangie tusail
# glenrothes reserve vintage
# gold seagram vo
# green johnnie walker
# harmony hibiki
# harper i.w.
# highland malt virginia
# highland mcclelland
# horse white
# house of stuart
# hudson manhattan rye
# islay mcclelland
# james jesse original
# jameson
# jefferson reserve
# johnnie platinum walker
# johnnie red walker
# jr. stagg
# keep masters turkey wild
# kentucky spirit turkey wild
# kettle kopper
# kilbeggan
# laphroaig lore
# laphroaig select
# laphroaig triplewood
# lowland mcclelland
# maker mark
# man
# mash michter sour
# michter us*1
# monkey shoulder
# old overholt rye
# old smuggler
# passport
# prichard
# rebel yell
# reserve rye woodford
# rye templeton
# select yellowstone
# spiced turkey wild
# storm talisker
# suntory toki
# tconnell

# %%
# for brand in va_new_brand:
#     matches = process.extract(brand, wa_new_whisky)
#     if matches[0][1] != 100:
#         print(brand, matches[0])

# %%
#va_df[va_df['new_brand'].str.contains('james')]

# %%
#w_archive[w_archive['new_whisky_name'].str.contains('stag')]

# %%
#va_df.to_csv('data_transformed/va_prices.csv', index=False)

# %%
#w_archive.to_csv('data_transformed/reddit_archive.csv', index=False)

# %% [markdown]
# ## Whisky Critic Matching

# %%
def my_wc_transform(s):
    """Function to transform brand
    * make lower
    * remove product types ex: 'bourbon', 'whiskey'
    """

    
    replacements = {"yo\W": " ",
                    "^prichard’s rye$": " prichard ",
                    "^reserve rye straight woodford$": "reserve rye woodford",
                    "^kentucky rebel yell": "rebel yell",
                    "laphroaig triple wood": "laphroaig triplewood",
                    "barrel four roses single": "four roses",
                    "founder glenlivet reserve": "founders glenlivet reserve",
                    "founder’s irishman reserve": "founders irishman reserve",
                    "carribean": "caribbean",
                    "12 glendronach original": "12 glendronach",
                    "dalwhinnie distillers edition": "dalwhinnie distiller edition",
                    "all distiller edition editions glenkinchie": "distiller edition glenkinchie",
                    "dalwhinnie distillers edition": "dalwhinnie distiller edition",
                    "ardbeg uigeadail": "ardbeg uigeadall",
                    "all daniel distiller jack master series": "daniel distiller jack master",
                    "21 balvenie port wood": "21 balvenie portwood",
                    "21 fine macallan oak": "21 fine macallan oak old",
                    "american auchentoshan oak": "american auchentosahn oak",
                    "basil haydens kentucky": "basil hayden",
                    "2016 cairdeas laphroaig madeira": "cairdeas laphroaig madeira",
                    "cooper croze jameson": "cooper croze",
                    "all distillers edition oban vintages": "distillers edition oban",
                    "16 glenlivet nadurra": "glenlivet nadurra",
                    "all midleton rare very vintages": "midleton rare",
                    "mortlach old rare": "mortlach rare",
                    "and rare rich": "rare rich",
                    "high redemption rye": "redemption rye",
                    "1792 finished port": "1792 finish port",
                    }
    for k, v in replacements.items():
        s = re.sub(k, v, s)
    
    replace = ["nas", ]
    
    for item in replace:
        s = s.replace(item, '')
    
    s = s.split() # remove extra spaces between words
    s.sort()
    s = " ".join(s)
    
    return s.strip()

# %%
my_wc_transform('my best 12yo scotch')
# Out:
# '12 best my scotch'

# %%
wc_df = pd.read_csv('../data_source/Meta-Critic Whisky Database.csv')
wc_df.columns = wc_df.columns.str.lower().str.replace(' ', '_')

# %%
wc_df['alt_brand'] = wc_df['whisky'].map(lambda x: my_va_transform(x))
wc_df['alt_brand'] = wc_df['alt_brand'].map(lambda x: my_wc_transform(x))

# %%
wc_new_whisky = wc_df['alt_brand'].tolist()

# %%
exact_matches = set()
for brand in va_new_brand:
    if brand in wc_new_whisky:
        exact_matches.add(brand)
print('Matches: {}'.format(len(exact_matches)))
exact_matches = list(exact_matches)
exact_matches.sort()
print('\n'.join(exact_matches))
# Out:
# Matches: 162
# 1 edition macallan
# 10 bulleit
# 10 eagle rare
# 10 fine macallan oak
# 10 old rip van winkle
# 101 turkey wild
# 114 dad grand old
# 12 balvenie barrel single
# 12 balvenie doublewood
# 12 bowmore
# 12 bunnahabhain
# 12 caol ila
# 12 cask double macallan
# 12 castle knappogue
# 12 chivas regal
# 12 craig elijah
# 12 dalmore
# 12 dickel george
# 12 glendronach
# 12 glenfiddich
# 12 glenlivet
# 12 hibiki
# 12 tomatin
# 12 yamazaki
# 14 balvenie caribbean cask
# 15 family pappy reserve van winkle
# 15 fine macallan oak
# 150th anniversary daniel jack
# 17 balvenie doublewood
# 17 fine macallan oak
# 1792 barrel single
# 1792 finish port
# 1792 full proof
# 1792 sweet wheat
# 18 chivas regal
# 18 glenlivet
# 18 laphroaig
# 18 oban
# 18 talisker
# 2 edition macallan
# 2 gingers
# 21 ardbeg
# 21 balvenie portwood
# 21 bushmills
# 21 fine macallan oak old
# 25 cragganmore
# 25 highland park
# 25 laphroaig
# 25 talisker
# 30 caol ila
# 30 fine macallan oak
# 30 talisker
# 40 lot
# 46 maker mark
# 6 reserve russell rye
# 75th anniversary crown monarch royal
# 8 islay mist
# 8 lagavulin
# 81 rye turkey wild
# 81 turkey wild
# aged at jefferson ocean sea
# alberta batch dark rye
# american auchentosahn oak
# american high prairie west
# american westland
# ardbeg auriverdes
# ardbeg corryvreckan
# ardbeg perpetuum
# ardbeg uigeadall
# auchentoshan three wood
# baby balcones blue
# barrel blanton single
# barrel creek forty select
# barrel creek knob reserve single
# barrel crown hand royal selected
# barrel daniel jack single
# barrel evan single williams
# barrel michter rye strength
# barrel reserve russell single
# basil hayden
# batch four roses small
# batch jefferson small very
# batch michter small
# bay little oban
# beam black jim
# beam cut devil jim
# beam jim rye
# black bush bushmills
# black crown royal
# black double johnnie walker
# black evan williams
# black johnnie walker
# blue johnnie walker
# booker rye
# breed rare turkey wild
# buffalo trace
# bulleit
# bulleit rye
# bunnahabhain toiteach
# cairdeas laphroaig madeira
# canadian mist
# cask glenrothes reserve
# cask glenrothes reserve sherry
# cask laphroaig quarter
# cask maker mark strength
# caskmates jameson
# coffey grain nikka
# colorado stranahan
# cooper croze
# crown harvest northern royal rye
# crown royal
# crown royal xo
# cutty prohibition sark
# cutty sark
# d'or glenmorangie nectar
# dalwhinnie distiller edition
# daniel distiller jack master
# daniel gentleman jack jack
# dark highland origins park
# dewar white
# dickel george rye
# distiller edition glenkinchie
# distillers edition oban
# double high rye west
# double oaked reserve woodford
# famous grouse
# forester old
# founders glenlivet reserve
# founders man reserve
# four roses
# glenlivet nadurra
# glenlivet nadurra oloroso
# glenmorangie lasanta
# glenmorangie milsean
# glenmorangie quinta ruban
# glenmorangie tusail
# glenrothes reserve vintage
# gold johnnie reserve walker
# green johnnie walker
# harmony hibiki
# jameson
# johnnie platinum walker
# johnnie red walker
# laphroaig lore
# laphroaig select
# laphroaig triplewood
# maker mark
# man
# mash michter sour
# midleton rare
# monkey shoulder
# mortlach rare
# rare rich
# rebel yell
# redemption rye
# reserve rye woodford
# reserve woodford
# rye templeton
# seagram vo
# storm talisker
# suntory toki
# tconnell

# %%
va_set = set(va_new_brand)
va_set = list(va_set)
va_set.sort()
for brand in va_set:
    matches = process.extract(brand, wc_new_whisky)
    if matches[0][1] >= 90 and matches[0][1] < 100:
        print(brand, matches[0])
# Out:
# 1 balcones texas ('balcones texas', 95)
# 10 ardbeg islay ('10 ardbeg', 90)
# 10 glenmorangie original the ('"original" 10 glenmorangie', 95)
# 100 comfort proof southern ('proof', 90)
# 100 dad grand old ('100 bib dad grand old', 95)
# 110 pikesville proof rye ('proof', 90)
# 12 aberlour ('18 aberlour', 91)
# 12 dew tullamore ('10 dew tullamore', 94)
# 12 dewar reserve special ('12 dewar', 90)
# 12 highland park ('25 highland park', 94)
# 12 jameson ('jameson', 95)
# 12 lagavulin ('16 lagavulin', 92)
# 12 macallan ('12 macallan oak sherry', 90)
# 12 reserve special van winkle ('12 b lot reserve special van winkle', 95)
# 14 glenfiddich ('18 glenfiddich', 93)
# 15 bowmore ('15 bowmore laimrig', 90)
# 15 caol ila ('25 caol ila', 91)
# 15 founders glenlivet reserve w/50ml ('founders glenlivet reserve', 95)
# 15 french glenlivet oak old reserve ('15 french glenlivet oak', 90)
# 16 aberlour ('18 aberlour', 91)
# 1776 barrel e. james pepper proof rye ('proof', 90)
# 18 jameson ('jameson', 95)
# 18 macallan ('18 macallan oak sherry', 90)
# 1870 forester old ('forester old', 95)
# 2016 batch edition four limited roses small ('batch edition four limited roses small', 95)
# 2016 birthday forester old ('2012 2016 birthday forester old', 95)
# 24 glenkinchie ('12 glenkinchie', 93)
# 25 macallan ('25 macallan oak sherry', 90)
# 30 macallan oak sherry ('10 macallan oak sherry', 95)
# 4 barrel daniel jack rye single ('barrel daniel jack rye single', 97)
# 8 dickel george ('12 dickel george', 90)
# 86 barton old proof very ('proof', 90)
# 92 catoctin creek proof roundstone rye ('proof', 90)
# age ancient ('10 age ancient kentucky straight', 90)
# aged at cask jefferson ocean sea strength ('jefferson ocean', 90)
# aged canadian club reserve triple ('9 canadian club reserve', 90)
# american maker mark pharaoh ('maker mark', 90)
# ardbeg supernova ('2014 ardbeg supernova', 95)
# ardbog ('ardbeg ardbog the ultimate', 90)
# baker ('7 bakers kentucky straight', 90)
# ballantine ('17 ballantine', 95)
# balvenie barrel single ('25 balvenie barrel single', 95)
# barley bruichladdich islay ('all barley bruichladdich islay vintages', 90)
# barrel barrel daniel jack proof single ('proof', 90)
# barrel batch edition four limited roses small ('batch edition four limited roses small', 95)
# barrel black jameson ('barrel black jameson reserve select', 90)
# barrel cork proof west ('proof', 90)
# barrel e h jr. proof taylor ('proof', 90)
# barrel four roses single ('four roses', 90)
# barrel henry mckenna single ('10 barrel bib henry mckenna single', 95)
# barrel reserve russell rye single ('barrel reserve russell single', 95)
# barterhouse ('20 barrel barterhouse orphan', 90)
# batch canadian classic club small ('12 batch canadian classic club small', 96)
# batch small teeling ('teeling', 90)
# beam jim ('beam jim pre prohibition rye', 90)
# black famous grouse smoky ('famous grouse', 90)
# black velvet ('3 black velvet', 95)
# blend gentleman kentucky ('man', 90)
# booker ('booker rye', 90)
# bowman ('man', 90)
# brandy collection finish master reserve woodford ('reserve woodford', 90)
# bushmills ('21 bushmills', 95)
# canadian club ('30 canadian club', 95)
# cask macallan rare ('1824 cask macallan rare', 95)
# chivas regal ('25 chivas regal', 95)
# classic collection master reserve woodford ('reserve woodford', 90)
# cragganmore ('25 cragganmore', 95)
# craig elijah ('21 craig elijah', 95)
# creek knob ('batch creek knob rye small straight', 90)
# creek knob rye ('batch creek knob rye small straight', 90)
# crown reserve royal special ('crown reserve royal', 95)
# crown royal vanilla ('crown royal', 90)
# crown royal xr ('crown royal', 95)
# dad grand old ('114 dad grand old', 95)
# dalwhinnie ('15 dalwhinnie', 95)
# daniel jack rested rye ('1/2 batch daniel jack rested rye', 95)
# derby reserve woodford ('reserve woodford', 95)
# dew tullamore ('10 dew tullamore', 95)
# fill first glenlivet nadurra ('fill first glenlivet nadurra oak white', 95)
# fleischmann preferred ('man', 90)
# forester old signature ('100 forester old proof signature', 95)
# gentleman virginia ('man', 90)
# ginger rebel yell ('rebel yell', 90)
# glenfiddich ('18 glenfiddich', 95)
# gold seagram vo ('seagram vo', 90)
# grant ('25 glen grant', 90)
# henry mckenna ('10 barrel bib henry mckenna single', 90)
# hudson manhattan rye ('man', 90)
# kilbeggan ('kilbeggan malt reserve', 90)
# lagavulin ('16 lagavulin', 95)
# laphroaig ('25 laphroaig', 95)
# larceny ('batch larceny small', 90)
# man quiet traditional ('man', 90)
# oban ('distillers edition oban', 90)
# old pulteney ('17 old pulteney', 95)
# olde ('golden schenley wedding', 90)
# plastic reserve woodford ('reserve woodford', 90)
# plastic seagram vo ('seagram vo', 90)
# power ('12 john lane powers', 90)
# prichard ('prichards rye', 90)
# speyburn ('10 speyburn', 95)
# talisker ('30 talisker', 95)
# teacher ('cream highland teacher', 90)

# %%
#wc_df.to_csv('data_transformed/meta_critic.csv', index=False)

# %% [markdown]
# ## Proof 66 matching

# %%
def my_proof_transform(s):
    """Function to transform brand
    * make lower
    * remove product types ex: 'bourbon', 'whiskey'
    """

    
    replacements = {"101 8 turkey wild": "101 turkey wild",
                    "114 dad grand old proof": "114 dad grand old",
                    "81 turkey wild": "81 rye turkey wild",
                   }
    for k, v in replacements.items():
        s = re.sub(k, v, s)
    
    replace = [ ]
    
    for item in replace:
        s = s.replace(item, '')
    
    s = s.split() # remove extra spaces between words
    s.sort()
    s = " ".join(s)
    
    return s.strip()

# %%
proof_df = pd.read_csv('../data_source/proof66.csv')
proof_df.columns = proof_df.columns.str.lower().str.replace(' ', '_')

# %%
proof_df['alt_brand'] = proof_df['name'].map(lambda x: my_va_transform(x))
proof_df['alt_brand'] = proof_df['alt_brand'].map(lambda x: my_proof_transform(x))

# %%
proof_new_whisky = proof_df['alt_brand'].tolist()

# %%
exact_matches = set()
for brand in va_new_brand:
    if brand in proof_new_whisky:
        exact_matches.add(brand)
print('Matches: {}'.format(len(exact_matches)))
exact_matches = list(exact_matches)
exact_matches.sort()
print('\n'.join(exact_matches))
# Out:
# Matches: 24
# 12 aberlour
# 12 bunnahabhain
# 12 caol ila
# 12 dalmore
# 12 glenfiddich
# 12 tomatin
# 15 balvenie cask sherry
# 16 aberlour
# 17 fine macallan oak
# 18 chivas regal
# 18 macallan
# 18 talisker
# 25 highland park
# 30 macallan oak sherry
# 30 talisker
# 8 islay mist
# 8 lagavulin
# ardbeg corryvreckan
# bay little oban
# black johnnie walker
# bradan orach speyburn
# cask laphroaig quarter
# green johnnie walker
# storm talisker

# %%
va_set = set(va_new_brand)
va_set = list(va_set)
va_set.sort()
for brand in va_set:
    matches = process.extract(brand, proof_new_whisky)
    if matches[0][1] >= 80 and matches[0][1] < 100:
        print(brand, matches[0])
# Out:
# "m" macallan ('21 douglas drumlanrig macallan', 86)
# ' blue johnnie of rooster' the walker ('blended hm king the', 86)
# . 10 barrel michter single ('10 aberlour', 86)
# 1 balcones texas ('1 5 bruichladdich octomore', 86)
# 1 box experiment set wood ('artists blend box compass great king st', 86)
# 1 edition macallan ('21 douglas drumlanrig macallan', 86)
# 10 ardbeg islay ('10 ardbeg', 90)
# 10 barrel limited michter release rye single ('10 aberlour', 86)
# 10 bulleit ('10 auchentoshan', 86)
# 10 cask sherry tamdhu ('10 aberlour', 86)
# 10 cork west ('10 benriach curiositas', 86)
# 10 eagle rare ('10 benriach curiositas', 86)
# 10 fine macallan oak ('17 fine macallan oak', 95)
# 10 glenmorangie original the ('10 glenmorangie', 90)
# 10 kinahan ('10 auchentoshan', 86)
# 10 old rip van winkle ('10 aberlour', 86)
# 10 reserve russell turkey wild ('10 aberlour', 86)
# 100 dad grand old ('bark grand', 86)
# 101 gold moonshine pro shiners sweetwater virginia ('18 blended clan gold', 86)
# 101 turkey wild ('13 mortlach scotsmans wild', 86)
# 114 dad grand old ('bark grand', 86)
# 12 balvenie barrel single ('12 aberfeldy', 86)
# 12 balvenie doublewood ('12 aberfeldy', 86)
# 12 beam jim signature ('12 aberfeldy', 86)
# 12 bowmore ('1982 bowmore', 91)
# 12 buchanan deluxe ('12 aberfeldy', 86)
# 12 cask double macallan ('12 aberfeldy', 86)
# 12 castle knappogue ('12 aberfeldy', 86)
# 12 chivas regal ('18 chivas regal', 93)
# 12 craig elijah ('12 aultmore foggie moss', 86)
# 12 dew tullamore ('12 balvenie batch signature', 86)
# 12 dewar reserve special ('12 aberfeldy', 86)
# 12 dickel george ('12 balvenie batch signature', 86)
# 12 glendronach ('18 glendronach', 93)
# 12 glenlivet ('21 glenlivet', 92)
# 12 hibiki ('12 arran cask strength', 86)
# 12 highland park ('15 highland park', 94)
# 12 jameson ('12 arran cask strength', 86)
# 12 lagavulin ('8 lagavulin', 87)
# 12 macallan ('10 macallan', 91)
# 12 medley old ('12 arran cask strength', 86)
# 12 old rye straight whistlepig world ('12 aberfeldy', 86)
# 12 reserve special van winkle ('12 aberfeldy', 86)
# 12 yamazaki ('12 arran cask strength', 86)
# 14 balvenie caribbean cask ('arran cask', 86)
# 14 dickel george whisey ('14 oban', 86)
# 14 glenfiddich ('12 glenfiddich', 93)
# 15 bowmore ('15 bowmore darkest', 90)
# 15 caol ila ('12 caol ila', 91)
# 15 family pappy reserve van winkle ('15 benriach solstice', 86)
# 15 fine macallan oak ('17 fine macallan oak', 95)
# 15 founders glenlivet reserve w/50ml ('15 balvenie cask sherry', 86)
# 15 french glenlivet oak old reserve ('15 french glenlivet oak', 90)
# 15 rye straight whistlepig ('15 glen scotia', 86)
# 16 and barrel lock rye stock straight ('16 aberlour', 86)
# 17 balvenie doublewood ('50 balvenie', 86)
# 17 masters turkey wild ('17 bowmore', 86)
# 1792 barrel single ('1975 cask glenfiddich scotch single', 86)
# 1792 batch small ('12 balvenie batch signature', 86)
# 1792 finish port ('ainsley brae burgundy finish', 86)
# 1792 full proof ('21 95 balvenie portwood proof', 86)
# 1792 high rye ('blended commissioner high', 86)
# 18 2 50ml chivas extra regal w/ ('18 battlehill jura', 86)
# 18 ancient glenfiddich reserve ('18 battlehill jura', 86)
# 18 barrel craig elijah single ('18 battlehill jura', 86)
# 18 buchanan deluxe ('18 caol ila', 86)
# 18 glenlivet ('21 glenlivet', 92)
# 18 glenmorangie original the ('18 glenmorangie', 90)
# 18 jameson ('18 auchentoshan sherry', 86)
# 18 laphroaig ('15 laphroaig', 92)
# 18 oban ('18 auchentoshan sherry', 86)
# 1838 collection corn master reserve white woodford ('cask dewars scratched white', 86)
# 1870 forester old ('highland mackinlays malt old rare', 86)
# 1889 brand old ('highland mackinlays malt old rare', 86)
# 18th century old potrero rye staight ('15 grand old parr', 86)
# 2 box experiment set wood ('artists blend box compass great king st', 86)
# 2 edition macallan ('21 douglas drumlanrig macallan', 86)
# 2014 barrel daniel holiday jack select single ('2014 cairdeas laphroaig', 86)
# 2015: blue johnnie of ram the walker ('blended hm king the', 86)
# 2016 batch edition four limited roses small ('12 balvenie batch signature', 86)
# 2016 birthday forester old ('15 grand old parr', 86)
# 2016 edition elliott four limited roses select ('1973 blended edition lonach', 86)
# 2016: blue johnnie monkey of the walker ('cask dreams glenfiddich of', 86)
# 21 archive glenlivet ('21 benromach', 86)
# 21 ardbeg ('10 ardbeg', 89)
# 21 balvenie portwood ('21 95 balvenie portwood proof', 95)
# 21 barrel craig elijah single ('21 ballantines', 86)
# 21 benrinnes ('21 95 balvenie portwood proof', 86)
# 21 bushmills ('21 95 balvenie portwood proof', 86)
# 21 fine macallan oak old ('17 fine macallan oak', 87)
# 21 rosebank ('21 95 balvenie portwood proof', 86)
# 23 barrel craig elijah single ('23 craigellachie', 86)
# 24 glenkinchie ('10 glenkinchie', 86)
# 25 cragganmore ('1992 cragganmore', 87)
# 25 lagavulin ('8 lagavulin', 87)
# 25 laphroaig ('15 laphroaig', 92)
# 25 macallan ('25 macallan oak sherry', 90)
# 25 talisker ('25 balvenie cask triple', 86)
# 30 caol ila ('8 alexander caol ila murray', 86)
# 30 fine macallan oak ('17 fine macallan oak', 90)
# 40 lot ('1965 40 auchentoshan', 86)
# 46 maker mark ('and jon mark one peaty robbos smokey', 86)
# 6 reserve russell rye ('12 blended blenders fort glen reserve', 86)
# 69 gold vat ('18 blended clan gold', 86)
# 8 beam star ('8 alexander caol ila murray', 86)
# 8 benchmark ('8 alexander caol ila murray', 86)
# 8 dickel george ('8 alexander caol ila murray', 86)
# 8 kentucky supreme ('8 alexander caol ila murray', 86)
# 81 turkey wild ('13 mortlach scotsmans wild', 86)
# 86 barton old proof very ('17 old pulteney', 86)
# 9 barrel dickel george hand selected ('9 marsala springbank', 86)
# 96 distillery geo.washington only proof rye unaged ('21 95 balvenie portwood proof', 86)
# abraham bowman cocoa finish gingerbread ('arran finish sherry', 86)
# aged at cask jefferson ocean sea strength ('ardmore cask traditional', 86)
# aged canadian club reserve triple ('laphroaig triple wood', 86)
# ale cask glenfiddich india pale ('arran cask', 86)
# alfred blue dunhill edition johnnie limited walker ('150th anniversary johnnie walker', 86)
# ambler old scout smooth ('17 old pulteney', 86)
# american auchentosahn oak ('american auchentoshan oak', 96)
# american honey sting turkey wild ('15 scotsman wild', 86)
# american honey turkey wild ('15 scotsman wild', 86)
# ancient glenfiddich reserve ('12 glenfiddich', 86)
# and rifle rod straight ('and b j', 86)
# angel barrel envy port ('29 ellen port', 86)
# angled frame glenmorangie open original the ('glenfiddich original', 86)
# apple bird dog ('8 black centenary dog', 86)
# apple crown regal royal ('18 chivas regal', 86)
# ardbeg auriverdes ('10 ardbeg', 86)
# ardbeg committee cove dark release ('10 ardbeg', 86)
# ardbeg perpetuum ('10 ardbeg', 86)
# ardbeg quadrant ('10 ardbeg', 86)
# ardbeg supernova ('10 ardbeg', 86)
# ardbeg uigeadall ('ardbeg uigeadail', 94)
# auchentoshan three wood ('10 auchentoshan', 86)
# b j rare ('highland mackinlays malt old rare', 86)
# b john stetson ('and b j', 86)
# ballantine ('ballantines finest', 90)
# balvenie barrel single ('50 balvenie', 86)
# barley bruichladdich islay ('barley bruichladdic classic laddie scottish', 86)
# barrel batch edition four limited roses small ('12 balvenie batch signature', 86)
# barrel beam jim single ('1975 cask glenfiddich scotch single', 86)
# barrel black jameson ('black cu dhub', 86)
# barrel blanton single ('1975 cask glenfiddich scotch single', 86)
# barrel single wathen ('1975 cask glenfiddich scotch single', 86)
# batch corsair rum small smoke triple ('12 balvenie cask triple', 86)
# batch e h small taylor ('40 big duncan scotch smoke taylor', 86)
# batch michter small ('1991 batch garioch glen small', 86)
# batch small teeling ('1991 batch garioch glen small', 86)
# beam black jim ('10 black blended bottle', 86)
# beam brandy finish jim signature ('arran finish sherry', 86)
# beam cask jim quarter signature ('arran cask', 86)
# beam cider hardcore jim red stag ('21 buchanans red seal', 86)
# beam cinnamon jim red spiced stag with ('21 buchanans red seal', 86)
# beam double jim oak ('blended box compass cross oak', 86)
# bird blackberry dog glass tervis w/ ('8 black centenary dog', 86)
# bird dog ('8 black centenary dog', 86)
# bird dog flavored grapefruit red ruby ('8 black centenary dog', 86)
# bird dog flavored honey jalapeno ('8 black centenary dog', 86)
# bird dog maple ('8 black centenary dog', 86)
# bird dog peach ('8 black centenary dog', 86)
# black bush bushmills ('black cu dhub', 86)
# black caramel toasted velvet ('42 black bowmore', 86)
# black carry evan pack williams ('42 black bowmore', 86)
# black cherry comfort southern ('42 black bowmore', 86)
# black cinnamon flavored rush velvet ('10 black blended bottle', 86)
# black cleveland reserve ('black cu dhub', 86)
# black cork reserve west ('black cu dhub', 86)
# black crown royal ('1964 29 black bowmore scotch', 86)
# black daniel jack seven ('black cu dhub', 86)
# black double johnnie walker ('black johnnie walker', 95)
# black evan williams ('black blended edition grand macnish', 86)
# black famous grouse smoky ('42 black bowmore', 86)
# black grouse ('10 black blended bottle', 86)
# black portable velvet ('black cu dhub', 86)
# black velvet ('10 black blended bottle', 86)
# black virginia ('10 black blended bottle', 86)
# blend classic clontarf ('barley bruichladdic classic laddie scottish', 86)
# blend gentleman kentucky ('artists blend box compass great king st', 86)
# blue johnnie walker ('black johnnie walker', 87)
# bowman brothers straight virginia ('50 brothers chivas', 86)
# bowman j john straight virginia ('and b j', 86)
# brandy collection finish master reserve woodford ('ainsley brae burgundy finish', 86)
# breast red ('21 buchanans red seal', 86)
# breed rare turkey wild ('highland mackinlays malt old rare', 86)
# brenne cask estate ('arran cask', 86)
# brown j.t.s. ('and b j', 86)
# bunnahabhain toiteach ('12 bunnahabhain', 85)
# bushmills old ('highland mackinlays malt old rare', 86)
# bushmills old tins ('highland mackinlays malt old rare', 86)
# cairdeas laphroaig madeira ('15 laphroaig', 86)
# calvert canadian decanter ducks lord unlimited ('15 blended elcho lord', 86)
# calvert extra ('blended chivas extra regal', 86)
# calvert lord ('15 blended elcho lord', 86)
# camp old peach pecan ('highland mackinlays malt old rare', 86)
# canada house ('green house inver plaid', 86)
# canadian easy mist pour ('8 islay mist', 86)
# canadian flavored maple mist mist ('blended highland mist', 86)
# canadian limited ('auchentoshan limited release valinch', 86)
# canadian mist ('blended highland mist', 86)
# caol distillers edition ila ('12 caol ila', 86)
# cask dewar scratched white ('cask dewars scratched white', 98)
# cask dual filibuster rye ('arran cask', 86)
# cask finish groth jefferson reserve ('12 arran cask strength', 86)
# cask glenrothes reserve ('alba glenrothes reserve', 87)
# cask glenrothes reserve sherry ('cask glenrothes sherry', 95)
# cask hudson maple rye ('arran cask', 86)
# cask macallan rare ('arran cask', 86)
# cask maker mark strength ('arran cask', 86)
# casks johnnie select walker ('2015 and collection john private sons walker', 86)
# chivas extra regal ('blended chivas extra regal', 95)
# chivas regal ('18 chivas regal', 95)
# clan macgregor ('blended clan macgregor', 90)
# clan macgregor plastic scotch ('10 glengoyne scotch', 86)
# classic collection master reserve woodford ('alba glenrothes reserve', 86)
# club haig ('blended haig supreme', 86)
# cluny ('blended cluny', 90)
# clyde may ('12 blended clyde glen', 86)
# clynelish reserve select ('12 blended blenders fort glen reserve', 86)
# coffey grain nikka ('18 dundas grain port single', 86)
# collection crown noble royal ('2015 and collection john private sons walker', 86)
# collection experiment jefferson wood ('17 balvenie new wood', 86)
# collection master reserve straight woodford ('alba glenrothes reserve', 86)
# corn white ('cask dewars scratched white', 86)
# cragganmore ('1992 cragganmore', 95)
# cragganmore distiller edition ('1992 cragganmore', 86)
# crow old ('15 grand old parr', 86)
# crow old reserve ('12 blended blenders fort glen reserve', 86)
# crow old traveler ('highland mackinlays malt old rare', 86)
# crown honey royal ('blended johnnie route royal walker', 86)
# crown plastic royal ('blended johnnie route royal walker', 86)
# crown royal ('blended johnnie route royal walker', 86)
# crown royal vanilla ('blended johnnie route royal walker', 86)
# crown royal xo ('blended johnnie route royal walker', 86)
# crown royal xr ('blended johnnie route royal walker', 86)
# cutty prohibition sark ('blended cutty prohibition sark', 95)
# cutty sark ('blended cutty prohibition sark', 86)
# d'or glenmorangie nectar ('dor glenmorangie nectar', 98)
# dad grand old ('150th anniversary blended grand macnish', 86)
# dalwhinnie ('1990 dalwhinnie', 90)
# dalwhinnie distiller edition ('1990 dalwhinnie', 86)
# dark highland origins park ('eades highland', 86)
# derby reserve woodford ('12 blended blenders fort glen reserve', 86)
# dewar reserve special ('12 blended blenders fort glen reserve', 86)
# dewar white ('cask dewars scratched white', 86)
# dickel george rye ('and george john king sons v walk', 86)
# distiller edition glenkinchie ('10 glenkinchie', 86)
# distiller edition talisker ('10 talisker', 86)
# distillers edition lagavulin ('8 lagavulin', 86)
# distillers edition oban ('black blended edition grand macnish', 86)
# distillery horn only war ('blended company distillery lossit lost malt', 86)
# double high rye west ('black blended double johnnie walker', 86)
# e h seasoned taylor wood ('blended duncan glory scottish taylor', 86)
# e. fitzgerald john reserve vs ('2015 and collection john private sons walker', 86)
# edition fire highland park ('eades highland', 86)
# ewing j. private r. reserve ('and b j', 86)
# famous grouse ('12 famous grouse', 95)
# fill first glenlivet nadurra ('18 glenlivet nadurra', 87)
# forester julep mint old ('17 old pulteney', 86)
# forester old ('highland mackinlays malt old rare', 86)
# forester old signature ('highland mackinlays malt old rare', 86)
# forged oak ('ainsley brae highland oak', 86)
# founders glenlivet reserve ('21 glenlivet', 86)
# founders man reserve ('12 blended blenders fort glen reserve', 86)
# four grain hudson ('18 dundas grain port single', 86)
# gentleman virginia ('blended gentleman malts smooth wemyss', 86)
# glenfiddich ('12 glenfiddich', 95)
# glenfiddich original the tin with ('glenfiddich original', 90)
# glenfiddich reserve solera ('12 glenfiddich', 86)
# glenlivet nadurra ('18 glenlivet nadurra', 95)
# glenlivet nadurra oloroso ('glenlivent nadurra oloroso', 98)
# glenmorangie lasanta ('12 glenmorangie lasanta', 95)
# glenmorangie milsean ('10 glenmorangie', 85)
# glenmorangie quinta ruban ('12 glenmorangie quinta ruban', 95)
# glenmorangie tusail ('10 glenmorangie', 85)
# glenrothes reserve vintage ('1972 glenrothes', 86)
# gold johnnie reserve walker ('gold johnnie walker', 95)
# gold seagram vo ('5 blended gold heritage', 86)
# grand macnish ('150th anniversary blended grand macnish', 90)
# grant ('25 douglas drumlanrig glen grant', 90)
# haller reserve ('12 blended blenders fort glen reserve', 86)
# high hiram ten walker ('2015 and collection john private sons walker', 86)
# highland malt virginia ('blended box compass elightenment malt', 86)
# highland mcclelland ('highland mackinlays malt old rare', 86)
# horse white ('cask dewars scratched white', 86)
# house inver ('green house inver plaid', 90)
# house of stuart ('cask dreams glenfiddich of', 86)
# imperial ('10 benromach imperial proof', 90)
# islay mcclelland ('islay mcclellands', 97)
# isle jura of ('1977 isle jura of', 95)
# james jesse original ('blended leader original scottish', 86)
# jefferson reserve ('12 blended blenders fort glen reserve', 86)
# johnnie platinum walker ('2015 and collection john private sons walker', 86)
# johnnie red walker ('2015 and collection john private sons walker', 86)
# keep masters turkey wild ('15 scotsman wild', 86)
# kentucky spirit turkey wild ('15 scotsman wild', 86)
# lagavulin ('8 lagavulin', 95)
# laphroaig ('15 laphroaig', 95)
# laphroaig lore ('10 cask laphroaig strength', 86)
# laphroaig select ('10 cask laphroaig strength', 86)
# laphroaig triplewood ('laphroaig triple wood', 98)
# maker mark ('and jon mark one peaty robbos smokey', 86)
# man ('islay kilchoman', 90)
# michter us*1 ('1 5 bruichladdich octomore', 86)
# midleton rare ('highland mackinlays malt old rare', 86)
# mortlach rare ('15 and gordon macphail mortlach', 86)
# oban ('14 oban', 90)
# old overholt rye ('highland mackinlays malt old rare', 86)
# old paddy ('15 grand old parr', 86)
# old pet taylor ('38 auld blended duncan taylor', 86)
# old pulteney ('17 old pulteney', 95)
# old smuggler ('blended old smuggler', 90)
# pet turkey wild ('13 mortlach scotsmans wild', 86)
# plastic reserve woodford ('12 blended blenders fort glen reserve', 86)
# rare rich ('highland mackinlays malt old rare', 86)
# rare scoresby ('highland mackinlays malt old rare', 86)
# reserve rye woodford ('12 blended blenders fort glen reserve', 86)
# reserve woodford ('12 blended blenders fort glen reserve', 86)
# speyburn ('25 speyburn', 95)
# supreme ('blended haig supreme', 90)
# talisker ('10 talisker', 95)
# teacher ('blended cream highland teachers', 90)
# windsor ('17 black blended windsor', 90)

# %%
proof_df.to_csv('data_transformed/proof66.csv', index=False)
