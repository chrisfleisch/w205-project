# %%
import re
import pandas as pd
import numpy as np

from fixerio import Fixerio
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from measurement.measures import Volume

# %%
va_df = pd.read_csv('data_source/VA-Price-List.csv', skiprows=1)
va_df.columns = va_df.columns.str.lower()

# %%
va_df = va_df[va_df.description.str.contains('WHISKEY') | va_df.description.str.contains('WHISKY')]
va_df.head()
# Out:
#                 description   code                       brand   size  age  \
# 0  STRAIGHT BOURBON WHISKEY  21228     1792 Bourbon Full Proof  750ml  NaN
# 1  STRAIGHT BOURBON WHISKEY  21232    1792 Port Finish Bourbon  750ml  NaN
# 2  STRAIGHT BOURBON WHISKEY  21244  1792 Single Barrel Bourbon  750ml  NaN
# 3  STRAIGHT BOURBON WHISKEY  21236    1792 Small Batch Bourbon  750ml  NaN
# 4  STRAIGHT BOURBON WHISKEY  21242    1792 Sweet Wheat Bourbon  750ml  NaN
#
#    proof    price
# 0  125.0  $47.99
# 1   88.9  $42.99
# 2   98.6  $42.99
# 3   93.7  $33.99
# 4   91.2  $39.99

# %%
va_df.describe()
# Out:
#                 code       proof
# count     871.000000  871.000000
# mean    20912.814007   84.514696
# std     19615.108155   13.127495
# min       137.000000    0.000000
# 25%      6897.500000   80.000000
# 50%     17920.000000   80.000000
# 75%     26114.500000   90.000000
# max    100124.000000  136.200000

# %%
va_df.brand.isnull().any()
# Out:
# False

# %%
def my_va_transform(s):
    """Function to transform brand
    * make lower
    * do specific regex replacements
    * remove product types ex: 'bourbon', 'whiskey'
    * sort the words in the brand
    """
    s = s.lower()
    
    replacements = {"^gentleman jack whiskey$": "jack daniel's gentleman jack",
                    "^pritchard": "prichard",
                    "^balcones baby blue corn whiskey$": "balcones baby blue",
                    "^canadian club rye whisky$": "canadian club",
                    "^catoctin creek roundstone rye whisky$": "catoctin creek roundstone rye",
                    "^e h taylor jr. straight rye$": "colonel e.h. taylor straight rye",
                    "^e h taylor seasoned wood$": "colonel e.h. taylor seasoned wood",
                    "^james e. pepper 1776 rye": "james e. pepper 1776 straight rye",
                    "^lock stock & barrel 16 yr straight rye whiskey$": "lock stock and barrel 16 straight rye",
                    "^michter's us 1 single barrel straight rye$": "michter's us*1",
                    "^michter's us-1 barrel strength rye": "michter's barrel strength rye",
                    "^old overholt$": "old overholt rye",
                    "^wild turkey russell's reserve rye$": "russell's reserve rye 6",
                    "\s7\s": " seven ",
                    "^defiant whisky$": "defiant",
                    "^michter's us1 sour mash$": "michter sour mash",
                    "^red stag": "jim beam red stag",
                    "^four roses 2015 limited edition small batch$": "four roses limited edition 2015",
                    "^four roses 2016 limited edition small batch$": "four roses small batch limited edition 2016",
                    "^i w harper bourbon$": "i.w. harper",
                    "^jesse james bourbon whiskey$": "original jesse james",
                    "^the": " ",
                    "scotch$": " ",
                    "-": " ",
                    }
    for k, v in replacements.items():
        s = re.sub(k, v, s)
    
    replace = ['bourbon', 'craft',
               'Year Single Barrel Bourbon',
               '-year Single Barrel Bourbon',
               'whiskey', 'tennessee whiskey', 'tennessee',
               'year', 'yr', '-year single barrel',
               'year single barrel', 'label', "'s",
               'decades', 'whisky', '&', 'single malt', "(", ")",
               "yo", "no.", "irish", "’", "us1",
               ]
    
    for item in replace:
        s = s.replace(item, '')
    
    s = s.split() # remove extra spaces betwen words and sort
    s.sort()
    s = " ".join(s)
    
    return s.strip()

# %%
my_va_transform('12 glenlivet malt single')
# Out:
# '12 glenlivet malt single'

# %%
va_df['alt_brand'] = va_df['brand'].map(lambda x: my_va_transform(x))
va_df.head()
# Out:
#                 description   code                       brand   size  age  \
# 0  STRAIGHT BOURBON WHISKEY  21228     1792 Bourbon Full Proof  750ml  NaN
# 1  STRAIGHT BOURBON WHISKEY  21232    1792 Port Finish Bourbon  750ml  NaN
# 2  STRAIGHT BOURBON WHISKEY  21244  1792 Single Barrel Bourbon  750ml  NaN
# 3  STRAIGHT BOURBON WHISKEY  21236    1792 Small Batch Bourbon  750ml  NaN
# 4  STRAIGHT BOURBON WHISKEY  21242    1792 Sweet Wheat Bourbon  750ml  NaN
#
#    proof    price           alt_brand         oz alt_price alt_age
# 0  125.0  $47.99      1792 full proof  25.360114    47.99      NaN
# 1   88.9  $42.99     1792 finish port  25.360114    42.99      NaN
# 2   98.6  $42.99   1792 barrel single  25.360114    42.99      NaN
# 3   93.7  $33.99     1792 batch small  25.360114    33.99      NaN
# 4   91.2  $39.99     1792 sweet wheat  25.360114    39.99      NaN

# %%
def my_size_transform(s):
    if 'ml' in s:
        v = Volume(milliliter=s.replace('ml', ''))
    elif 'L' in s:
        v = Volume(liter=s.replace('L', ''))
    return v.us_oz

# %%
va_df['oz'] = va_df['size'].map(lambda x: my_size_transform(x))
va_df['alt_price'] = va_df['price'].str.replace('$', '')
va_df['alt_age'] = va_df['age'].str.replace('YR', '')

# %%
w_archive = pd.read_csv('data_source/Reddit Whisky Network Review Archive - Review Archive.csv',
                        names=['timestamp', 'whisky_name', 'reviewer_username', 'link',
                               'rating', 'style', 'bottle_price', 'review_date'],
                        skiprows=1,
                        parse_dates=['timestamp', 'review_date'])

# %%
w_archive['rating'] = pd.to_numeric(w_archive['rating'], errors='coerce')
#w_archive['bottle_price'] = pd.to_numeric(w_archive['bottle_price'], errors='coerce')
w_archive['timestamp'] = pd.to_datetime(w_archive['timestamp'], errors='coerce')
w_archive['review_date'] = pd.to_datetime(w_archive['review_date'], errors='coerce')
w_archive['whisky_name'] = w_archive.whisky_name.str.lower()
w_archive['style'] = w_archive['style'].str.lower()
w_archive.dtypes
# Out:
# timestamp            datetime64[ns]
# whisky_name                  object
# reviewer_username            object
# link                         object
# rating                      float64
# style                        object
# bottle_price                 object
# review_date          datetime64[ns]
# dtype: object

# %%
#w_archive.head(20)

# %%
fxrio = Fixerio(base='USD')
conversion = fxrio.latest()
import math

def isnumber(num):
    return all(char.isdigit() for char in num)

def transform_currency(s):
    if 'CAD' in str(s) or 'CDN' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['CAD'])
        return new_price
    elif '£' in str(s) or 'GBP' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['GBP'])
        return new_price
    elif 'AUD' in str(s) or 'AUS' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['AUD'])
        return new_price
    elif 'NZD' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['NZD'])
        return new_price
    elif 'EUR' in str(s) or '€' in str(s) or 'Euro' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['EUR'])
        return new_price
    elif 'SEK' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['SEK'])
        return new_price
    elif 'RMB' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['CNY'])
        return new_price
    elif 'DKR' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['DKK'])
        return new_price
    elif 'HKD' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['HKD'])
        return new_price
    elif 'JPY' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['JPY'])
        return new_price
    elif 'ZAR' in str(s):
        price = re.sub(r"""[^0-9]+""", '', s)
        new_price = float(price) / float(conversion['rates']['ZAR'])
        return new_price
    elif type(s) == str and isnumber(s):
        # USD
        return s
    elif type(s) == float and math.isnan(s):
        # NAN
        return s
    elif re.match(r"""^\$*\d+\.*\d+$""", s):
        s = s.replace('$', '')
        return s
    else:
        # Convert everything else to NAN
        print(s)
        return None

# %%
w_archive['alt_brand'] = w_archive['whisky_name'].map(lambda x: my_va_transform(x))
w_archive['alt_bottle_price'] = w_archive['bottle_price'].map(lambda x: transform_currency(x))
#w_archive.head(100)
# Out:
# $270 ARS

# %%
va_new_brand = va_df['alt_brand'].tolist()
wa_new_whisky = w_archive['alt_brand'].tolist()

# %%
exact_matches = set()
for brand in va_new_brand:
    if brand in wa_new_whisky:
        exact_matches.add(brand)
print('Matches: {}'.format(len(exact_matches)))
exact_matches = list(exact_matches)
exact_matches.sort()
print('\n'.join(exact_matches))
# Out:
# Matches: 237
# 1 edition macallan
# 10 bulleit
# 10 cork west
# 10 eagle rare
# 10 fine macallan oak
# 10 glenmorangie original the
# 10 old rip van winkle
# 101 turkey wild
# 114 dad grand old
# 12 balvenie doublewood
# 12 beam jim signature
# 12 bowmore
# 12 bunnahabhain
# 12 caol ila
# 12 cask double macallan
# 12 castle knappogue
# 12 chivas regal
# 12 craig elijah
# 12 dalmore
# 12 dewar reserve special
# 12 dickel george
# 12 glendronach
# 12 glenfiddich
# 12 glenlivet
# 12 hibiki
# 12 highland park
# 12 jameson
# 12 lagavulin
# 12 macallan
# 12 medley old
# 12 tomatin
# 12 yamazaki
# 14 balvenie caribbean cask
# 15 family pappy reserve van winkle
# 15 fine macallan oak
# 16 aberlour
# 16 and barrel lock rye stock straight
# 17 balvenie doublewood
# 17 fine macallan oak
# 1776 barrel e. james pepper proof rye
# 1776 e. james pepper rye straight
# 1783 evan williams
# 1792 batch small
# 1792 finish port
# 1792 full proof
# 1792 high rye
# 1792 sweet wheat
# 18 chivas regal
# 18 glenlivet
# 18 jameson
# 18 laphroaig
# 18 macallan
# 18 oban
# 18 talisker
# 1843 david nicholson
# 1870 forester old
# 2 edition macallan
# 2015 edition four limited roses
# 2016 batch edition four limited roses small
# 2016 birthday forester old
# 21 archive glenlivet
# 21 balvenie portwood
# 21 bushmills
# 21 rosebank
# 25 highland park
# 25 talisker
# 30 caol ila
# 30 talisker
# 40 lot
# 46 maker mark
# 6 reserve russell rye
# 75th anniversary crown monarch royal
# 8 dickel george
# 8 islay mist
# 8 lagavulin
# 81 turkey wild
# age ancient
# american westland
# angel envy rye
# ardbeg auriverdes
# ardbeg committee cove dark release
# ardbeg corryvreckan
# ardbeg perpetuum
# auchentoshan three wood
# baby balcones blue
# baby hudson
# barrel barrel daniel jack proof single
# barrel beam jim single
# barrel creek forty select
# barrel creek knob reserve single
# barrel crown hand royal selected
# barrel daniel jack single
# barrel evan single williams
# barrel four roses single
# barrel michter rye strength
# barrel reserve russell rye single
# barrel reserve russell single
# barrel single wathen
# basil hayden
# batch craig elijah small
# batch four roses small
# batch hirsch reserve small
# batch jefferson small very
# batch michter small
# batch small teeling
# bay little oban
# beam black jim
# beam bonded jim
# beam choice jim
# beam cider hardcore jim red stag
# beam cinnamon jim red spiced stag with
# beam cut devil jim
# beam double jim oak
# beam honey jim
# beam jim
# beam jim red stag
# beam jim rye
# belle meade
# black bush bushmills
# black crown royal
# black double johnnie walker
# black evan williams
# black famous grouse smoky
# black grouse
# black johnnie walker
# black velvet
# black virginia
# blue johnnie walker
# booker
# booker rye
# bradan orach speyburn
# breckenridge
# breed rare turkey wild
# buffalo trace
# bulleit
# bulleit rye
# bunnahabhain toiteach
# canadian club
# canadian mist
# cask finish groth jefferson reserve
# cask glenrothes reserve
# cask glenrothes reserve sherry
# cask laphroaig quarter
# cask macallan rare
# cask maker mark strength
# catoctin creek roundstone rye
# chivas extra regal
# clan macgregor
# club haig
# cock fighting
# coffey grain nikka
# colorado stranahan
# comfort southern
# copper fox rye
# creek knob
# creek knob maple smoked
# creek knob rye
# crow old
# crow old reserve
# crown harvest northern royal rye
# crown reserve royal special
# crown royal
# crown seagram seven
# cutty sark
# d'or glenmorangie nectar
# dalwhinnie distiller edition
# daniel gentleman jack jack
# daniel honey jack
# dark highland origins park
# dead guy rogue
# defiant
# dew phoenix tullamore
# dew tullamore
# dewar highlander honey
# dewar white
# dickel george rye
# distiller edition talisker
# double high rye west
# double oaked reserve woodford
# early times
# edition fire highland park
# evan green williams
# famous grouse
# filibuster
# fill first glenlivet nadurra
# forester old
# forester old signature
# forgiven turkey wild
# four grain hudson
# gentleman virginia
# glenlivet nadurra oloroso
# glenmorangie lasanta
# glenmorangie milsean
# glenmorangie quinta ruban
# glenmorangie tusail
# glenrothes reserve vintage
# gold seagram vo
# green johnnie walker
# harmony hibiki
# harper i.w.
# highland malt virginia
# highland mcclelland
# horse white
# house of stuart
# hudson manhattan rye
# islay mcclelland
# james jesse original
# jameson
# jefferson reserve
# johnnie platinum walker
# johnnie red walker
# jr. stagg
# keep masters turkey wild
# kentucky spirit turkey wild
# kettle kopper
# kilbeggan
# laphroaig lore
# laphroaig select
# laphroaig triplewood
# lowland mcclelland
# maker mark
# man
# mash michter sour
# michter us*1
# monkey shoulder
# old overholt rye
# old smuggler
# passport
# prichard
# rebel yell
# reserve rye woodford
# rye templeton
# select yellowstone
# spiced turkey wild
# storm talisker
# suntory toki
# tconnell

# %%
# for brand in va_new_brand:
#     matches = process.extract(brand, wa_new_whisky)
#     if matches[0][1] != 100:
#         print(brand, matches[0])

# %%
#va_df[va_df['new_brand'].str.contains('james')]

# %%
#w_archive[w_archive['new_whisky_name'].str.contains('stag')]

# %%
va_df.to_csv('data_transformed/va_prices.csv', index=False)

# %%
w_archive.to_csv('data_transformed/reddit_archive.csv', index=False)

# %% [markdown]
# ## Whisky Critic Matching

# %%
def my_wc_transform(s):
    """Function to transform brand
    * make lower
    * remove product types ex: 'bourbon', 'whiskey'
    """

    
    replacements = {"yo\W": " ",
                    "^prichard’s rye$": " prichard ",
                    "^reserve rye straight woodford$": "reserve rye woodford",
                    "^kentucky rebel yell": "rebel yell",
                    "laphroaig triple wood": "laphroaig triplewood",
                    "barrel four roses single": "four roses",
                    "founder glenlivet reserve": "founders glenlivet reserve",
                    "founder’s irishman reserve": "founders irishman reserve",
                    "carribean": "caribbean",
                    "12 glendronach original": "12 glendronach",
                    "dalwhinnie distillers edition": "dalwhinnie distiller edition",
                    "all distiller edition editions glenkinchie": "distiller edition glenkinchie",
                    "dalwhinnie distillers edition": "dalwhinnie distiller edition",
                    "ardbeg uigeadail": "ardbeg uigeadall",
                    "all daniel distiller jack master series": "daniel distiller jack master",
                    "21 balvenie port wood": "21 balvenie portwood",
                    "21 fine macallan oak": "21 fine macallan oak old",
                    "american auchentoshan oak": "american auchentosahn oak",
                    "basil haydens kentucky": "basil hayden",
                    "2016 cairdeas laphroaig madeira": "cairdeas laphroaig madeira",
                    "cooper croze jameson": "cooper croze",
                    "all distillers edition oban vintages": "distillers edition oban",
                    "16 glenlivet nadurra": "glenlivet nadurra",
                    "all midleton rare very vintages": "midleton rare",
                    "mortlach old rare": "mortlach rare",
                    "and rare rich": "rare rich",
                    "high redemption rye": "redemption rye",
                    "1792 finished port": "1792 finish port",
                    }
    for k, v in replacements.items():
        s = re.sub(k, v, s)
    
    replace = ["nas", ]
    
    for item in replace:
        s = s.replace(item, '')
    
    s = s.split() # remove extra spaces between words
    s.sort()
    s = " ".join(s)
    
    return s.strip()

# %%
my_wc_transform('my best 12yo scotch')
# Out:
# '12 best my scotch'

# %%
wc_df = pd.read_csv('data_source/Meta-Critic Whisky Database.csv')
wc_df.columns = wc_df.columns.str.lower().str.replace(' ', '_')

# %%
wc_df['alt_brand'] = wc_df['whisky'].map(lambda x: my_va_transform(x))
wc_df['alt_brand'] = wc_df['alt_brand'].map(lambda x: my_wc_transform(x))

# %%
wc_new_whisky = wc_df['alt_brand'].tolist()

# %%
exact_matches = set()
for brand in va_new_brand:
    if brand in wc_new_whisky:
        exact_matches.add(brand)
print('Matches: {}'.format(len(exact_matches)))
exact_matches = list(exact_matches)
exact_matches.sort()
print('\n'.join(exact_matches))
# Out:
# Matches: 162
# 1 edition macallan
# 10 bulleit
# 10 eagle rare
# 10 fine macallan oak
# 10 old rip van winkle
# 101 turkey wild
# 114 dad grand old
# 12 balvenie barrel single
# 12 balvenie doublewood
# 12 bowmore
# 12 bunnahabhain
# 12 caol ila
# 12 cask double macallan
# 12 castle knappogue
# 12 chivas regal
# 12 craig elijah
# 12 dalmore
# 12 dickel george
# 12 glendronach
# 12 glenfiddich
# 12 glenlivet
# 12 hibiki
# 12 tomatin
# 12 yamazaki
# 14 balvenie caribbean cask
# 15 family pappy reserve van winkle
# 15 fine macallan oak
# 150th anniversary daniel jack
# 17 balvenie doublewood
# 17 fine macallan oak
# 1792 barrel single
# 1792 finish port
# 1792 full proof
# 1792 sweet wheat
# 18 chivas regal
# 18 glenlivet
# 18 laphroaig
# 18 oban
# 18 talisker
# 2 edition macallan
# 2 gingers
# 21 ardbeg
# 21 balvenie portwood
# 21 bushmills
# 21 fine macallan oak old
# 25 cragganmore
# 25 highland park
# 25 laphroaig
# 25 talisker
# 30 caol ila
# 30 fine macallan oak
# 30 talisker
# 40 lot
# 46 maker mark
# 6 reserve russell rye
# 75th anniversary crown monarch royal
# 8 islay mist
# 8 lagavulin
# 81 rye turkey wild
# 81 turkey wild
# aged at jefferson ocean sea
# alberta batch dark rye
# american auchentosahn oak
# american high prairie west
# american westland
# ardbeg auriverdes
# ardbeg corryvreckan
# ardbeg perpetuum
# ardbeg uigeadall
# auchentoshan three wood
# baby balcones blue
# barrel blanton single
# barrel creek forty select
# barrel creek knob reserve single
# barrel crown hand royal selected
# barrel daniel jack single
# barrel evan single williams
# barrel michter rye strength
# barrel reserve russell single
# basil hayden
# batch four roses small
# batch jefferson small very
# batch michter small
# bay little oban
# beam black jim
# beam cut devil jim
# beam jim rye
# black bush bushmills
# black crown royal
# black double johnnie walker
# black evan williams
# black johnnie walker
# blue johnnie walker
# booker rye
# breed rare turkey wild
# buffalo trace
# bulleit
# bulleit rye
# bunnahabhain toiteach
# cairdeas laphroaig madeira
# canadian mist
# cask glenrothes reserve
# cask glenrothes reserve sherry
# cask laphroaig quarter
# cask maker mark strength
# caskmates jameson
# coffey grain nikka
# colorado stranahan
# cooper croze
# crown harvest northern royal rye
# crown royal
# crown royal xo
# cutty prohibition sark
# cutty sark
# d'or glenmorangie nectar
# dalwhinnie distiller edition
# daniel distiller jack master
# daniel gentleman jack jack
# dark highland origins park
# dewar white
# dickel george rye
# distiller edition glenkinchie
# distillers edition oban
# double high rye west
# double oaked reserve woodford
# famous grouse
# forester old
# founders glenlivet reserve
# founders man reserve
# four roses
# glenlivet nadurra
# glenlivet nadurra oloroso
# glenmorangie lasanta
# glenmorangie milsean
# glenmorangie quinta ruban
# glenmorangie tusail
# glenrothes reserve vintage
# gold johnnie reserve walker
# green johnnie walker
# harmony hibiki
# jameson
# johnnie platinum walker
# johnnie red walker
# laphroaig lore
# laphroaig select
# laphroaig triplewood
# maker mark
# man
# mash michter sour
# midleton rare
# monkey shoulder
# mortlach rare
# rare rich
# rebel yell
# redemption rye
# reserve rye woodford
# reserve woodford
# rye templeton
# seagram vo
# storm talisker
# suntory toki
# tconnell

# %%
va_set = set(va_new_brand)
va_set = list(va_set)
va_set.sort()
for brand in va_set:
    matches = process.extract(brand, wc_new_whisky)
    if matches[0][1] >= 90 and matches[0][1] < 100:
        print(brand, matches[0])
# Out:
# 1 balcones texas ('balcones texas', 95)
# 10 ardbeg islay ('10 ardbeg', 90)
# 10 glenmorangie original the ('"original" 10 glenmorangie', 95)
# 100 comfort proof southern ('proof', 90)
# 100 dad grand old ('100 bib dad grand old', 95)
# 110 pikesville proof rye ('proof', 90)
# 12 aberlour ('18 aberlour', 91)
# 12 dew tullamore ('10 dew tullamore', 94)
# 12 dewar reserve special ('12 dewar', 90)
# 12 highland park ('25 highland park', 94)
# 12 jameson ('jameson', 95)
# 12 lagavulin ('16 lagavulin', 92)
# 12 macallan ('12 macallan oak sherry', 90)
# 12 reserve special van winkle ('12 b lot reserve special van winkle', 95)
# 14 glenfiddich ('18 glenfiddich', 93)
# 15 bowmore ('15 bowmore laimrig', 90)
# 15 caol ila ('25 caol ila', 91)
# 15 founders glenlivet reserve w/50ml ('founders glenlivet reserve', 95)
# 15 french glenlivet oak old reserve ('15 french glenlivet oak', 90)
# 16 aberlour ('18 aberlour', 91)
# 1776 barrel e. james pepper proof rye ('proof', 90)
# 18 jameson ('jameson', 95)
# 18 macallan ('18 macallan oak sherry', 90)
# 1870 forester old ('forester old', 95)
# 2016 batch edition four limited roses small ('batch edition four limited roses small', 95)
# 2016 birthday forester old ('2012 2016 birthday forester old', 95)
# 24 glenkinchie ('12 glenkinchie', 93)
# 25 macallan ('25 macallan oak sherry', 90)
# 30 macallan oak sherry ('10 macallan oak sherry', 95)
# 4 barrel daniel jack rye single ('barrel daniel jack rye single', 97)
# 8 dickel george ('12 dickel george', 90)
# 86 barton old proof very ('proof', 90)
# 92 catoctin creek proof roundstone rye ('proof', 90)
# age ancient ('10 age ancient kentucky straight', 90)
# aged at cask jefferson ocean sea strength ('jefferson ocean', 90)
# aged canadian club reserve triple ('9 canadian club reserve', 90)
# american maker mark pharaoh ('maker mark', 90)
# ardbeg supernova ('2014 ardbeg supernova', 95)
# ardbog ('ardbeg ardbog the ultimate', 90)
# baker ('7 bakers kentucky straight', 90)
# ballantine ('17 ballantine', 95)
# balvenie barrel single ('25 balvenie barrel single', 95)
# barley bruichladdich islay ('all barley bruichladdich islay vintages', 90)
# barrel barrel daniel jack proof single ('proof', 90)
# barrel batch edition four limited roses small ('batch edition four limited roses small', 95)
# barrel black jameson ('barrel black jameson reserve select', 90)
# barrel cork proof west ('proof', 90)
# barrel e h jr. proof taylor ('proof', 90)
# barrel four roses single ('four roses', 90)
# barrel henry mckenna single ('10 barrel bib henry mckenna single', 95)
# barrel reserve russell rye single ('barrel reserve russell single', 95)
# barterhouse ('20 barrel barterhouse orphan', 90)
# batch canadian classic club small ('12 batch canadian classic club small', 96)
# batch small teeling ('teeling', 90)
# beam jim ('beam jim pre prohibition rye', 90)
# black famous grouse smoky ('famous grouse', 90)
# black velvet ('3 black velvet', 95)
# blend gentleman kentucky ('man', 90)
# booker ('booker rye', 90)
# bowman ('man', 90)
# brandy collection finish master reserve woodford ('reserve woodford', 90)
# bushmills ('21 bushmills', 95)
# canadian club ('30 canadian club', 95)
# cask macallan rare ('1824 cask macallan rare', 95)
# chivas regal ('25 chivas regal', 95)
# classic collection master reserve woodford ('reserve woodford', 90)
# cragganmore ('25 cragganmore', 95)
# craig elijah ('21 craig elijah', 95)
# creek knob ('batch creek knob rye small straight', 90)
# creek knob rye ('batch creek knob rye small straight', 90)
# crown reserve royal special ('crown reserve royal', 95)
# crown royal vanilla ('crown royal', 90)
# crown royal xr ('crown royal', 95)
# dad grand old ('114 dad grand old', 95)
# dalwhinnie ('15 dalwhinnie', 95)
# daniel jack rested rye ('1/2 batch daniel jack rested rye', 95)
# derby reserve woodford ('reserve woodford', 95)
# dew tullamore ('10 dew tullamore', 95)
# fill first glenlivet nadurra ('fill first glenlivet nadurra oak white', 95)
# fleischmann preferred ('man', 90)
# forester old signature ('100 forester old proof signature', 95)
# gentleman virginia ('man', 90)
# ginger rebel yell ('rebel yell', 90)
# glenfiddich ('18 glenfiddich', 95)
# gold seagram vo ('seagram vo', 90)
# grant ('25 glen grant', 90)
# henry mckenna ('10 barrel bib henry mckenna single', 90)
# hudson manhattan rye ('man', 90)
# kilbeggan ('kilbeggan malt reserve', 90)
# lagavulin ('16 lagavulin', 95)
# laphroaig ('25 laphroaig', 95)
# larceny ('batch larceny small', 90)
# man quiet traditional ('man', 90)
# oban ('distillers edition oban', 90)
# old pulteney ('17 old pulteney', 95)
# olde ('golden schenley wedding', 90)
# plastic reserve woodford ('reserve woodford', 90)
# plastic seagram vo ('seagram vo', 90)
# power ('12 john lane powers', 90)
# prichard ('prichards rye', 90)
# speyburn ('10 speyburn', 95)
# talisker ('30 talisker', 95)
# teacher ('cream highland teacher', 90)

# %%
wc_df.to_csv('data_transformed/meta_critic.csv', index=False)

# %% [markdown]
# ## Proof 66 matching

# %%
def my_proof_transform(s):
    """Function to transform brand
    * make lower
    * remove product types ex: 'bourbon', 'whiskey'
    """

    
    replacements = {"101 8 turkey wild": "101 turkey wild",
                    "114 dad grand old proof": "114 dad grand old",
                    "81 turkey wild": "81 rye turkey wild",
                   }
    for k, v in replacements.items():
        s = re.sub(k, v, s)
    
    replace = [ ]
    
    for item in replace:
        s = s.replace(item, '')
    
    s = s.split() # remove extra spaces between words
    s.sort()
    s = " ".join(s)
    
    return s.strip()

# %%
proof_df = pd.read_csv('data_source/proof66.csv')
proof_df.columns = proof_df.columns.str.lower().str.replace(' ', '_')

# %%
proof_df['alt_brand'] = proof_df['name'].map(lambda x: my_va_transform(x))
proof_df['alt_brand'] = proof_df['alt_brand'].map(lambda x: my_proof_transform(x))

# %%
proof_new_whisky = proof_df['alt_brand'].tolist()

# %%
exact_matches = set()
for brand in va_new_brand:
    if brand in proof_new_whisky:
        exact_matches.add(brand)
print('Matches: {}'.format(len(exact_matches)))
exact_matches = list(exact_matches)
exact_matches.sort()
print('\n'.join(exact_matches))
# Out:
# Matches: 29
# 101 turkey wild
# 114 dad grand old
# 1792 barrel single
# 1843 david nicholson
# 81 rye turkey wild
# age ancient
# ambler old scout smooth
# b john stetson
# baby hudson
# barrel beam jim single
# barrel creek knob reserve single
# basil hayden
# beam cask jim quarter signature
# beam choice jim
# beam double jim oak
# belle meade
# buffalo trace
# bulleit
# crow old
# double oaked reserve woodford
# duke
# elmer lee t
# evan green williams
# forester old
# forester old signature
# four roses
# gentleman virginia
# joseph magnus
# rebel yell

# %%
va_set = set(va_new_brand)
va_set = list(va_set)
va_set.sort()
for brand in va_set:
    matches = process.extract(brand, proof_new_whisky)
    if matches[0][1] >= 80 and matches[0][1] < 100:
        print(brand, matches[0])
# Out:
# ' blue johnnie of rooster' the walker ('america of spirit', 86)
# . 10 barrel michter single ('25 barrel michters single', 90)
# 1 balcones texas ('1835 texas', 86)
# 10 ardbeg islay ('10 bond bottled henry in mckenna', 86)
# 10 barrel limited michter release rye single ('1792 barrel single', 86)
# 10 bulleit ('bulleit', 95)
# 10 cask sherry tamdhu ('10 bond bottled henry in mckenna', 86)
# 10 cork west ('10 bond bottled henry in mckenna', 86)
# 10 eagle rare ('17 eagle rare', 92)
# 10 fine macallan oak ('10 bond bottled henry in mckenna', 86)
# 10 glenmorangie original the ('10 michters', 86)
# 10 kinahan ('10 bond bottled henry in mckenna', 86)
# 10 old rip van winkle ('colonel eh fashioned mash old sour taylor', 86)
# 10 reserve russell turkey wild ('10 michters', 86)
# 100 comfort proof southern ('finish high madeira revival southern wire', 86)
# 100 dad grand old ('100 charles goodnight proof', 86)
# 101 gold moonshine pro shiners sweetwater virginia ('bowman brothers virginia', 86)
# 101 turkey wild ('101 8 turkey wild', 95)
# 114 dad grand old ('114 dad grand old proof', 95)
# 12 balvenie barrel single ('12 creek rowans', 86)
# 12 beam jim signature ('beam brown jim rice signature', 87)
# 12 bowmore ('12 creek rowans', 86)
# 12 cask double macallan ('amador barrel double napa valley wine', 86)
# 12 chivas regal ('ch', 90)
# 12 craig elijah ('18 craig elijah', 93)
# 12 dalmore ('12 creek rowans', 86)
# 12 dewar reserve special ('5 and henry j patton reserve road sons', 86)
# 12 glendronach ('ch', 90)
# 12 glenfiddich ('ch', 90)
# 12 hibiki ('12 creek rowans', 86)
# 12 jameson ('12 creek rowans', 86)
# 12 medley old ('colonel eh fashioned mash old sour taylor', 86)
# 12 old rye straight whistlepig world ('heaven hill old style', 86)
# 12 reserve special van winkle ('rebel reserve', 86)
# 12 tomatin ('12 creek rowans', 86)
# 13 barrel lock rye stock ('amador barrel double napa valley wine', 86)
# 13th colony corn southern ('13th colony southern', 95)
# 14 dickel george whisey ('george stagg t', 86)
# 14 glenfiddich ('ch', 90)
# 15 bowmore ('15 jeffersons reserve', 86)
# 15 caol ila ('15 jeffersons reserve', 86)
# 15 family pappy reserve van winkle ('15 jeffersons reserve', 86)
# 15 founders glenlivet reserve w/50ml ('blantons reserve special', 86)
# 15 french glenlivet oak old reserve ('heaven hill old style', 86)
# 16 and barrel lock rye stock straight ('1792 barrel single', 86)
# 17 balvenie doublewood ('17 eagle rare', 86)
# 17 fine macallan oak ('17 eagle rare', 86)
# 17 masters turkey wild ('17 eagle rare', 86)
# 1776 barrel e. james pepper proof rye ('1792 barrel single', 86)
# 1776 e. james pepper rye straight ('james jesse', 86)
# 1783 evan williams ('bond bottled evan in williams', 86)
# 1792 batch small ('ch', 90)
# 1792 finish port ('barrel cadee deceptivus port', 86)
# 1792 full proof ('100 charles goodnight proof', 86)
# 1792 high rye ('american high prairie reserve west', 86)
# 1792 sweet wheat ('1838 mash reserve sweet woodford', 86)
# 18 2 50ml chivas extra regal w/ ('18 craig elijah', 86)
# 18 ancient glenfiddich reserve ('age ancient', 86)
# 18 barrel craig elijah single ('1792 barrel single', 86)
# 18 chivas regal ('ch', 90)
# 18 glenmorangie original the ('18 craig elijah', 86)
# 18 jameson ('18 craig elijah', 86)
# 18 oban ('18 craig elijah', 86)
# 1838 collection corn master reserve white woodford ('blantons reserve special', 86)
# 1870 forester old ('forester old', 95)
# 1889 brand old ('colonel eh fashioned mash old sour taylor', 86)
# 18th century old potrero rye staight ('heaven hill old style', 86)
# 2 blood oath: pact ('1 blood oath pact', 91)
# 2 distillery geo. only rye straight washington ('291 colorado distillery', 86)
# 2001 creek knob ('barrel creek knob reserve single', 86)
# 2014 barrel daniel holiday jack select single ('1792 barrel single', 86)
# 2015 7 edition ksbw limited stone yellow ('7 kirkland', 86)
# 2015 edition four limited roses ('four roses', 86)
# 2015: blue johnnie of ram the walker ('america of spirit', 86)
# 2016 7 edition limited yellowstone ('7 kirkland', 86)
# 2016 batch edition four limited roses small ('001 barrell batch', 86)
# 2016 birthday forester old ('2006 birthday forester old', 96)
# 2016 edition elliott four limited roses select ('2014 barrel four roses single', 86)
# 2016: blue johnnie monkey of the walker ('america of spirit', 86)
# 21 ardbeg ('21 black hill maple', 86)
# 21 barrel craig elijah single ('1792 barrel single', 86)
# 21 benrinnes ('21 black hill maple', 86)
# 21 bushmills ('21 black hill maple', 86)
# 21 fine macallan oak old ('colonel eh fashioned mash old sour taylor', 86)
# 21 rosebank ('21 black hill maple', 86)
# 23 barrel craig elijah single ('1792 barrel single', 86)
# 24 bib heritage parker ('10 heritage hope of parkers promise', 86)
# 24 glenkinchie ('ch', 90)
# 25 cragganmore ('25 barrel michters single', 86)
# 25 highland park ('25 barrel michters single', 86)
# 25 lagavulin ('25 barrel michters single', 86)
# 25 laphroaig ('25 barrel michters single', 86)
# 25 macallan ('25 barrel michters single', 86)
# 25 talisker ('25 barrel michters single', 86)
# 4 barrel daniel jack rye single ('1792 barrel single', 86)
# 46 maker mark ('makers mark', 83)
# 6 reserve russell rye ('6 big house', 86)
# 6 rye sazerac ('6 barrel single willett', 86)
# 69 gold vat ('bardstown gold old', 86)
# 75th anniversary crown monarch royal ('5th anniversary balcones', 86)
# 8 beam star ('2013 7 american beam jim stillhouse', 86)
# 8 benchmark ('ch', 90)
# 8 dickel george ('8 end oak oregon trails', 86)
# 8 islay mist ('8 end oak oregon trails', 86)
# 8 kentucky supreme ('8 jeffersons', 86)
# 8 lagavulin ('8 end oak oregon trails', 86)
# 81 rye turkey wild ('81 turkey wild', 95)
# 86 barton old proof very ('colonel eh fashioned mash old sour taylor', 86)
# 9 barrel dickel george hand selected ('1792 barrel single', 86)
# 92 catoctin creek proof roundstone rye ('barrel homestead proof', 86)
# 96 distillery geo.washington only proof rye unaged ('100 charles goodnight proof', 86)
# abraham bowman cocoa finish gingerbread ('abraham bowman cocoa gingerbread', 95)
# abraham bowman edition limited wheat ('bowman brothers virginia', 86)
# age ancient ancient ('age ancient', 90)
# age ancient traveler ('age ancient', 90)
# aged at cask jefferson ocean sea strength ('angels cask envy strength', 86)
# aged canadian club reserve triple ('15 jeffersons reserve', 86)
# alfred blue dunhill edition johnnie limited walker ('22 and blade bow limited release', 86)
# american bare knuckle wheat ('20 american hirsch', 86)
# american high prairie west ('american high prairie reserve west', 95)
# american honey sting turkey wild ('american bearded lady', 86)
# american honey turkey wild ('101 8 turkey wild', 86)
# american maker mark pharaoh ('coopers mark', 86)
# american westland ('american high prairie reserve west', 86)
# ancient glenfiddich reserve ('age ancient', 86)
# and rifle rod straight ('5 and henry j patton reserve road sons', 86)
# angel barrel envy port ('amador barrel double napa valley wine', 86)
# angel envy rye ('angels cask envy strength', 86)
# apple beam jim ('apple cleveland underground wood', 86)
# apple bird dog ('apple cleveland underground wood', 86)
# apple kettle kopper ('apple cleveland underground wood', 86)
# apple orchard seagram ('apple cleveland underground wood', 86)
# b j rare ('17 eagle rare', 86)
# baby balcones blue ('baby hudson', 86)
# balvenie barrel single ('amador barrel double napa valley wine', 86)
# baron kaine robber rye virgil ('high redemption rye', 86)
# barrel barrel daniel jack proof single ('1792 barrel single', 86)
# barrel batch edition four limited roses small ('1792 barrel single', 86)
# barrel belle meade single ('belle meade', 90)
# barrel black jameson ('amador barrel double napa valley wine', 86)
# barrel blanton single ('amador barrel double napa valley wine', 86)
# barrel cork proof west ('amador barrel double napa valley wine', 86)
# barrel creek forty select ('creek paddleford', 86)
# barrel crown hand royal selected ('1792 barrel single', 86)
# barrel daniel jack single ('1792 barrel single', 80)
# barrel e h jr. proof taylor ('1792 barrel single', 86)
# barrel evan single williams ('1792 barrel single', 86)
# barrel four roses single ('2014 barrel four roses single', 95)
# barrel henry mckenna single ('1792 barrel single', 86)
# barrel michter rye strength ('1792 barrel single', 86)
# barrel reserve russell rye single ('barrel reserve russells single', 92)
# barrel reserve russell single ('barrel reserve russells single', 98)
# barrel single wathen ('amador barrel double napa valley wine', 86)
# barterhouse ('20 barrel barterhouse orphan', 90)
# batch canadian classic club small ('001 barrell batch', 86)
# batch corsair rum small smoke triple ('001 barrell batch', 86)
# batch craig elijah small ('18 craig elijah', 86)
# batch e h small taylor ('colonel eh fashioned mash old sour taylor', 86)
# batch four roses small ('four roses', 90)
# batch hirsch reserve small ('001 barrell batch', 86)
# batch jefferson small very ('001 barrell batch', 86)
# batch michter small ('batch colonel eh small taylor', 86)
# batch rebel rye small yell ('001 barrell batch', 86)
# batch small teeling ('batch colonel eh small taylor', 86)
# beam black jim ('batch black hill maple small', 86)
# beam bonded jim ('100 beam bonded jim proof', 90)
# beam brandy finish jim signature ('beam brandy finished jim signature', 97)
# beam candy cane jim pack trial ('beam choice jim', 86)
# beam cider hardcore jim red stag ('beam choice jim', 86)
# beam cinnamon jim red spiced stag with ('100 beam bonded jim proof', 86)
# beam cut devil jim ('2013 7 american beam jim stillhouse', 86)
# beam distiller jim masterpiece ('beam choice jim', 86)
# beam eight star ('2013 7 american beam jim stillhouse', 86)
# beam fire jim kentucky ('2013 7 american beam jim stillhouse', 86)
# beam flavor jim pack ('2013 7 american beam jim stillhouse', 86)
# beam homefront jim operation plastic ('beam choice jim', 86)
# beam honey jim ('2013 7 american beam jim stillhouse', 86)
# beam honey jim red stag tea ('beam choice jim', 86)
# beam jim ('2013 7 american beam jim stillhouse', 90)
# beam jim maple ('batch black hill maple small', 86)
# beam jim plastic ('2013 7 american beam jim stillhouse', 86)
# beam jim plastic red stag ('beam choice jim', 86)
# beam jim red stag ('2013 7 american beam jim stillhouse', 86)
# beam jim rye ('2013 7 american beam jim stillhouse', 86)
# beam jim seven ('2013 7 american beam jim stillhouse', 86)
# beam jim traveler ('2013 7 american beam jim stillhouse', 86)
# beer rebel root yell ('rebel reserve', 86)
# belle finish meade sherry ('belle meade', 86)
# bib tucker ('tucker', 90)
# bird dog flavored grapefruit red ruby ('red river texas', 86)
# bird dog maple ('batch black hill maple small', 86)
# bird dog peach ('ch', 90)
# black bush bushmills ('black eagle', 86)
# black caramel toasted velvet ('black eagle', 86)
# black carry evan pack williams ('black eagle', 86)
# black cherry comfort southern ('black eagle', 86)
# black cinnamon flavored rush velvet ('black eagle', 86)
# black cleveland reserve ('black eagle', 86)
# black cork reserve west ('black eagle', 86)
# black crown royal ('black eagle', 86)
# black daniel jack seven ('black eagle', 86)
# black double johnnie walker ('black eagle', 86)
# black evan williams ('black eagle', 86)
# black famous grouse smoky ('black eagle', 86)
# black grouse ('14 black hill maple', 86)
# black johnnie walker ('black eagle', 86)
# black portable velvet ('black eagle', 86)
# black velvet ('14 black hill maple', 86)
# black virginia ('batch black hill maple small', 86)
# blend gentleman kentucky ('gentleman kentucky', 95)
# booker ('bookers', 92)
# booker rye ('high redemption rye', 86)
# bounce cherry chicken cock ('6 cock fighting', 86)
# bowman ('abraham bowman cocoa gingerbread', 90)
# bowman brothers straight virginia ('bowman brothers virginia', 95)
# bowman j john straight virginia ('bowman j john', 90)
# brandy collection finish master reserve woodford ('blantons reserve special', 86)
# breast red ('red river texas', 86)
# breckenridge ('barrel breckenridge single', 90)
# breed rare turkey wild ('17 eagle rare', 86)
# brenne cask estate ('cask groth jeffersons reserve', 86)
# brooks ezra ('90pf brooks ezra', 95)
# bros. medley straight ('bros illinois laughton quincy street', 86)
# brown j.t.s. ('brown jts', 90)
# bulleit rye ('bulleit', 90)
# burnside ('4 burnside distilling eastside', 90)
# bushmills old ('colonel eh fashioned mash old sour taylor', 86)
# bushmills old tins ('colonel eh fashioned mash old sour taylor', 86)
# cabin fever flavored maple ('cabin still', 86)
# cabin fever maple ('batch black hill maple small', 86)
# cairdeas laphroaig madeira ('finish high madeira revival southern wire', 86)
# camp old peach pecan ('colonel eh fashioned mash old sour taylor', 86)
# canadian flavored maple mist mist ('14 black hill maple', 86)
# canadian limited ('22 and blade bow limited release', 86)
# canadian rare reserve rich ('17 eagle rare', 86)
# caol distillers edition ila ('distillers yankee', 86)
# caramel comfort southern ('finish high madeira revival southern wire', 86)
# cask finish groth jefferson reserve ('cask groth jeffersons reserve', 88)
# cask glenrothes reserve ('5 and henry j patton reserve road sons', 86)
# cask glenrothes reserve sherry ('rebel reserve', 86)
# cask hudson maple rye ('baby hudson', 86)
# cask macallan rare ('cask groth jeffersons reserve', 86)
# cask maker mark strength ('coopers mark', 86)
# casks johnnie select walker ('select watkins', 86)
# catoctin creek mosby rye spirit ('creek paddleford', 86)
# catoctin creek roundstone rye ('creek paddleford', 86)
# chivas regal ('ch', 90)
# cider evan kentucky williams ('gentleman kentucky', 86)
# classic collection master reserve woodford ('blantons reserve special', 86)
# clynelish reserve select ('5 and henry j patton reserve road sons', 86)
# cock fighting ('6 cock fighting', 95)
# collection master reserve straight woodford ('blantons reserve special', 86)
# colonel pride ('colonel eh fashioned mash old sour taylor', 86)
# comfort plastic southern ('finish high madeira revival southern wire', 86)
# comfort southern ('finish high madeira revival southern wire', 86)
# corn white ('corn platte valley', 86)
# craig elijah ('18 craig elijah', 95)
# creek knob ('barrel creek knob reserve single', 90)
# creek knob maple smoked ('12 creek rowans', 86)
# creek knob rye ('barrel creek knob reserve single', 86)
# crow old reserve ('crow old', 90)
# crow old traveler ('crow old', 90)
# crown harvest northern royal rye ('high redemption rye', 86)
# crown reserve royal special ('rebel reserve', 86)
# dad grand old ('114 dad grand old proof', 90)
# daniel holiday jack select ('select watkins', 86)
# daniel jack select sinatra ('select watkins', 86)
# dant j.w. ('5 and henry j patton reserve road sons', 86)
# derby reserve woodford ('american high prairie reserve west', 86)
# dewar reserve special ('american high prairie reserve west', 86)
# diamond turkey wild ('anniversary diamond turkey wild', 90)
# distillers edition lagavulin ('distillers yankee', 86)
# distillery horn only war ('buck horn', 86)
# distillery only rabble rouser rye straight ('291 colorado distillery', 86)
# distlllery george only rye washington ('george stagg t', 86)
# double high rye west ('amador barrel double napa valley wine', 86)
# e h jr. rye straight taylor ('colonel eh fashioned mash old sour taylor', 86)
# e h seasoned taylor wood ('colonel eh fashioned mash old sour taylor', 86)
# e. fitzgerald john reserve vs ('b john stetson', 86)
# evan fire williams ('bond bottled evan in williams', 86)
# evan honey williams ('bond bottled evan in williams', 86)
# evan peach williams ('bond bottled evan in williams', 86)
# evan white williams ('bond bottled evan in williams', 86)
# ewing j. private r. reserve ('bowman j john', 86)
# forester julep mint old ('colonel eh fashioned mash old sour taylor', 86)
# forged oak ('beam double jim oak', 86)
# forgiven turkey wild ('101 kentucky spirit turkey wild', 86)
# founders glenlivet reserve ('rebel reserve', 86)
# founders man reserve ('american high prairie reserve west', 86)
# four grain hudson ('2009 barrel four roses strength', 86)
# ginger rebel yell ('rebel yell', 90)
# glenfiddich ('ch', 90)
# glenfiddich reserve solera ('rebel reserve', 86)
# glenrothes reserve vintage ('kentucky vintage', 86)
# gold johnnie reserve walker ('colorado gold', 86)
# grand macnish ('114 dad grand old proof', 86)
# haig haig pinch ('ch', 90)
# haller reserve ('blantons reserve special', 86)
# harper i.w. ('harper iw', 95)
# henry mckenna ('10 bond bottled henry in mckenna', 86)
# high hiram ten walker ('american high prairie reserve west', 86)
# highland malt virginia ('6 old virginia', 86)
# house of stuart ('10 heritage hope of parkers promise', 86)
# hudson manhattan rye ('baby hudson', 86)
# isle jura of ('10 heritage hope of parkers promise', 86)
# james jesse original ('james jesse', 90)
# jefferson reserve ('15 jeffersons reserve', 89)
# jp rye wiser ('high redemption rye', 86)
# jr. stagg ('george stagg t', 86)
# keep masters turkey wild ('81 turkey wild', 86)
# kentucky spirit turkey wild ('101 kentucky spirit turkey wild', 95)
# kentucky tavern ('101 kentucky spirit turkey wild', 86)
# maker mark ('makers mark', 95)
# man ('bowman brothers virginia', 90)
# mash michter sour ('colonel eh fashioned mash old sour taylor', 86)
# mattingly moore ('bond bottled in moore tom', 86)
# michter us*1 ('ch', 90)
# mortlach rare ('ch', 90)
# old overholt rye ('colonel eh fashioned mash old sour taylor', 86)
# old paddy ('colonel eh fashioned mash old sour taylor', 86)
# old pet taylor ('colonel eh fashioned mash old sour taylor', 86)
# old pulteney ('colonel eh fashioned mash old sour taylor', 86)
# old smuggler ('colonel eh fashioned mash old sour taylor', 86)
# pet turkey wild ('101 kentucky spirit turkey wild', 86)
# plastic reserve woodford ('5 and henry j patton reserve road sons', 86)
# pogues ('old pogue', 82)
# prichard ('ch', 90)
# rare rich ('ch', 90)
# redemption rye ('high redemption rye', 95)
# reserve rye woodford ('american high prairie reserve west', 86)
# reserve woodford ('double oaked reserve woodford', 90)
# rhetoric ('20 barrel orphan rhetoric', 90)
# ri1 rye ('high redemption rye', 86)
# rye sagamore spirit ('101 kentucky spirit turkey wild', 86)
# spiced turkey wild ('101 kentucky spirit turkey wild', 86)
# teacher ('ch', 90)

# %%
proof_df.to_csv('data_transformed/proof66.csv', index=False)
